# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
import numpy as np
import imgaug.augmenters as iaa
import cv2
import statistics
import pandas as pd
import math
from skimage.transform import hough_circle
from skimage.feature import canny

# %%
umbrellas_files = ["umbrellas.png", "umbrellas-source.png"]

# %%
umbrellas = cv2.imread(umbrellas_files[0],0)
_, umbrellas = cv2.threshold(umbrellas, 128, 255, cv2.THRESH_BINARY)
plt.figure(figsize = (20,20))
plt.imshow(umbrellas)

# %%
edges = cv2.Canny(umbrellas,0,1)
plt.figure(figsize = (20,20))
plt.imshow(edges)

# %%
template = cv2.imread(umbrellas_files[3],0)
